# %%
# 형태소 분석: twitter
# Busan
from PIL import Image
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

mapreduce_output_path = '/Users/minseo/Documents/전공/빅데프/Team Project/맵리듀스/result/Busan_mapreduce_result.txt'

with open(mapreduce_output_path, 'r', encoding='utf-8-sig') as f:
    mapreduce_output = f.read()

word_frequencies = {}
for line in mapreduce_output.strip().split('\n'):
    try:
        word, count = line.split()
        word_frequencies[word] = int(count)
    except ValueError:
        print(f"Skipping line: {line}")

img = Image.open('/Users/minseo/Documents/전공/빅데프/Team Project/부산3.jpeg')
img_array = np.array(img)
print(img)


if word_frequencies:
    width = 800
    height = 800
    
    wordcloud = WordCloud(width=width, height=height,background_color='white',font_path='AppleGothic',mask=img_array).generate_from_frequencies(word_frequencies)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
else:
    print("No words to generate a word cloud.")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1300x1232 at 0x13ADF9650>

# %%
# 형태소 분석: twitter
# 대전
from PIL import Image
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

mapreduce_output_path = '/Users/minseo/Documents/전공/빅데프/Team Project/맵리듀스/result/Daejeon_mapreduce_result.txt'

with open(mapreduce_output_path, 'r', encoding='utf-8-sig') as f:
    mapreduce_output = f.read()

word_frequencies = {}
for line in mapreduce_output.strip().split('\n'):
    try:
        word, count = line.split()
        word_frequencies[word] = int(count)
    except ValueError:
        print(f"Skipping line: {line}")

img = Image.open('/Users/minseo/Documents/전공/빅데프/Team Project/대전.jpeg')
img_array = np.array(img)


if word_frequencies:
    width = 800
    height = 800
    
    wordcloud = WordCloud(width=width, height=height,background_color='white',font_path='Pretendard-Bold',mask=img_array).generate_from_frequencies(word_frequencies)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
else:
    print("No words to generate a word cloud.")

# %%
# 형태소 분석: twitter
# 인천
from PIL import Image
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

mapreduce_output_path = '/Users/minseo/Documents/전공/빅데프/Team Project/맵리듀스/result/Incheon_mapreduce_result.txt'

with open(mapreduce_output_path, 'r', encoding='utf-8-sig') as f:
    mapreduce_output = f.read()

word_frequencies = {}
for line in mapreduce_output.strip().split('\n'):
    try:
        word, count = line.split()
        word_frequencies[word] = int(count)
    except ValueError:
        print(f"Skipping line: {line}")

img = Image.open('/Users/minseo/Documents/전공/빅데프/Team Project/인천4.jpeg')
img_array = np.array(img)


if word_frequencies:
    width = 800
    height = 800
    
    wordcloud = WordCloud(width=width, height=height,background_color='white',font_path='Pretendard-Bold',mask=img_array).generate_from_frequencies(word_frequencies)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
else:
    print("No words to generate a word cloud.")

# %%
# 형태소 분석: twitter
# 제주
from PIL import Image
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

mapreduce_output_path = '/Users/minseo/Documents/전공/빅데프/Team Project/맵리듀스/result/Jeju_mapreduce_result.txt'

with open(mapreduce_output_path, 'r', encoding='utf-8-sig') as f:
    mapreduce_output = f.read()

word_frequencies = {}
for line in mapreduce_output.strip().split('\n'):
    try:
        word, count = line.split()
        word_frequencies[word] = int(count)
    except ValueError:
        print(f"Skipping line: {line}")

img = Image.open('/Users/minseo/Documents/전공/빅데프/Team Project/제주.jpeg')
img_array = np.array(img)


if word_frequencies:
    width = 800
    height = 800
    
    wordcloud = WordCloud(width=width, height=height,background_color='white',font_path='Pretendard-Bold',mask=img_array).generate_from_frequencies(word_frequencies)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
else:
    print("No words to generate a word cloud.")

# %%
# 형태소 분석: twitter
# 대구
from PIL import Image
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt

mapreduce_output_path = '/Users/minseo/Documents/전공/빅데프/Team Project/맵리듀스/result/Daegu_mapreduce_result.txt'

with open(mapreduce_output_path, 'r', encoding='utf-8-sig') as f:
    mapreduce_output = f.read()

word_frequencies = {}
for line in mapreduce_output.strip().split('\n'):
    try:
        word, count = line.split()
        word_frequencies[word] = int(count)
    except ValueError:
        print(f"Skipping line: {line}")

img = Image.open('/Users/minseo/Documents/전공/빅데프/Team Project/대구.jpeg')
img_array = np.array(img)


if word_frequencies:
    width = 800
    height = 800
    
    wordcloud = WordCloud(width=width, height=height,background_color='white',font_path='Pretendard-Bold',mask=img_array).generate_from_frequencies(word_frequencies)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
else:
    print("No words to generate a word cloud.")
